# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.fft import ifft, fft, fftfreq, fftshift, ifft2, fft2
from scipy.io import wavfile
from scipy.signal import hilbert
from audio_function import *
# Out:
# Данные загружены

# %%
fs, data_calibr = wavfile.read('/Users/bogda/Desktop/Acoustics/Scientific/Исходные данные/PGD_1020/2025_1020_1938/MIC2.WAV')
fs, data_60cm = wavfile.read('/Users/bogda/Desktop/Acoustics/Scientific/Исходные данные/PGD_1020/2025_1020_1945/MIC2.WAV')
fs, data_120cm = wavfile.read('/Users/bogda/Desktop/Acoustics/Scientific/Исходные данные/PGD_1020/2025_1020_1947/MIC2.WAV')
fs, data_180cm = wavfile.read('/Users/bogda/Desktop/Acoustics/Scientific/Исходные данные/PGD_1020/2025_1020_1950/MIC2.WAV')
fs, data_240cm = wavfile.read('/Users/bogda/Desktop/Acoustics/Scientific/Исходные данные/PGD_1020/2025_1020_1953/MIC2.WAV')
fs, data_315cm = wavfile.read('/Users/bogda/Desktop/Acoustics/Scientific/Исходные данные/PGD_1020/2025_1020_2001/MIC2.WAV')
# Out:
# /var/folders/lf/x86pzptd3pv7z45l56wggyjc0000gn/T/ipykernel_19462/3866503165.py:1: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   fs, data_calibr = wavfile.read('/Users/bogda/Desktop/Acoustics/Scientific/Исходные данные/PGD_1020/2025_1020_1938/MIC2.WAV')
# /var/folders/lf/x86pzptd3pv7z45l56wggyjc0000gn/T/ipykernel_19462/3866503165.py:2: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   fs, data_60cm = wavfile.read('/Users/bogda/Desktop/Acoustics/Scientific/Исходные данные/PGD_1020/2025_1020_1945/MIC2.WAV')
# /var/folders/lf/x86pzptd3pv7z45l56wggyjc0000gn/T/ipykernel_19462/3866503165.py:3: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   fs, data_120cm = wavfile.read('/Users/bogda/Desktop/Acoustics/Scientific/Исходные данные/PGD_1020/2025_1020_1947/MIC2.WAV')
# /var/folders/lf/x86pzptd3pv7z45l56wggyjc0000gn/T/ipykernel_19462/3866503165.py:4: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   fs, data_180cm = wavfile.read('/Users/bogda/Desktop/Acoustics/Scientific/Исходные данные/PGD_1020/2025_1020_1950/MIC2.WAV')
# /var/folders/lf/x86pzptd3pv7z45l56wggyjc0000gn/T/ipykernel_19462/3866503165.py:5: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   fs, data_240cm = wavfile.read('/Users/bogda/Desktop/Acoustics/Scientific/Исходные данные/PGD_1020/2025_1020_1953/MIC2.WAV')
# /var/folders/lf/x86pzptd3pv7z45l56wggyjc0000gn/T/ipykernel_19462/3866503165.py:6: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   fs, data_315cm = wavfile.read('/Users/bogda/Desktop/Acoustics/Scientific/Исходные данные/PGD_1020/2025_1020_2001/MIC2.WAV')

# %%
# octave_boundaries = np.array([71, 89, 112, 141, 179, 224, 281, 355, 447, 561, 710, 895, 1120, 1410, 1790, 2240, 2810, 3550, 4470, 5610, 7100, 8950, 11200])
# lower_bounds = octave_boundaries[:-1]
# upper_bounds = octave_boundaries[1:]
# center_freqs = np.array([80, 100, 125, 160, 200, 250, 315, 400, 500, 630, 800, 1000, 1250, 1600, 2000, 2500, 3150, 4000, 5000, 6300, 8000, 10000])  # Центральные частоты как середина диапазона

# %%
octave_boundaries = np.array([71, 89, 112, 141, 179, 224, 281, 355, 447, 561, 710, 895, 1120, 1410, 1790, 2240, 2810])
lower_bounds = octave_boundaries[:-1]
upper_bounds = octave_boundaries[1:]
center_freqs = np.array([80, 100, 125, 160, 200, 250, 315, 400, 500, 630, 800, 1000, 1250, 1600, 2000, 2500])  # Центральные частоты как середина диапазона
RMS_microphone_60 = []
RMS_microphone_120 = []
RMS_microphone_180 = []
RMS_microphone_240 = []
RMS_microphone_315 = []

# %%
signal = data_120cm
t = np.arange(len(signal))/fs
f = fftfreq(len(signal), 1 / fs)
plt.figure(figsize=(16,4))
plt.plot(f, np.abs(fft(signal)), color='blue')
plt.legend()
plt.xlabel("Гц")
plt.ylabel("Амплитуда")
plt.grid(True)
plt.xlim(0,500)
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
RMS_microphone = [RMS_microphone_60, RMS_microphone_120, RMS_microphone_180, RMS_microphone_240, RMS_microphone_315]
signals = [data_60cm, data_120cm, data_180cm, data_240cm, data_315cm]
for i in range (0,len(RMS_microphone)):
    signal = signals[i]
    for f1, f2 in zip(lower_bounds, upper_bounds):
        data_filt = ifft(filt_freq(fft(signal), f1, f2, fs))
        amp = RMS(data_filt)
        RMS_microphone[i].append(amp)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 6
#       4 signal = signals[i]
#       5 for f1, f2 in zip(lower_bounds, upper_bounds):
# ----> 6     data_filt = ifft(filt_freq(fft(signal), f1, f2, fs))
#       7     amp = RMS(data_filt)
#       8     RMS_microphone[i].append(amp)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/scipy/fft/_backend.py:28, in _ScipyBackend.__ua_function__(method, args, kwargs)
#      26 if fn is None:
#      27     return NotImplemented
# ---> 28 return fn(*args, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/scipy/fft/_basic_backend.py:66, in ifft(x, n, axis, norm, overwrite_x, workers, plan)
#      64 def ifft(x, n=None, axis=-1, norm=None, overwrite_x=False, workers=None, *,
#      65          plan=None):
# ---> 66     return _execute_1D('ifft', _pocketfft.ifft, x, n=n, axis=axis, norm=norm,
#      67                        overwrite_x=overwrite_x, workers=workers, plan=plan)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/scipy/fft/_basic_backend.py:28, in _execute_1D(func_str, pocketfft_func, x, n, axis, norm, overwrite_x, workers, plan)
#      25 xp = array_namespace(x)
#      27 if is_numpy(xp):
# ---> 28     return pocketfft_func(x, n=n, axis=axis, norm=norm,
#      29                           overwrite_x=overwrite_x, workers=workers, plan=plan)
#      31 norm = _validate_fft_args(workers, plan, norm)
#      32 if hasattr(xp, 'fft'):
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/scipy/fft/_pocketfft/basic.py:31, in c2c(forward, x, n, axis, norm, overwrite_x, workers, plan)
#      27     raise ValueError(message)
#      29 out = (tmp if overwrite_x and tmp.dtype.kind == 'c' else None)
# ---> 31 return pfft.c2c(tmp, (axis,), forward, norm, out, workers)
#
# KeyboardInterrupt:

# %%
len(RMS_microphone)
# Out:
# 5

# %%
RMS_distance = np.transpose(RMS_microphone)

# %%
len(RMS_distance[0])
# Out:
# 5

# %%
x = np.linspace(60, 315, 300)
distance = [60, 120, 180, 240, 315]
RMS_microphone_norm = RMS_distance

for i in range (0,len(RMS_microphone_norm)):
    RMS_microphone_norm[i] = RMS_microphone_norm[i]/np.max(RMS_microphone_norm[i])


def func (x):
    return 130/x

for i in range (0, len(RMS_distance[1:])):

    plt.figure(figsize=(12,4))
    plt.scatter(distance, RMS_distance[i], label = "Эксперимент", color = 'red')
    plt.plot(x, func(x), label = 'Теория')
    plt.grid(True)
    plt.xlabel("L, См")
    plt.ylabel("Нормированная амплитуда")
    plt.title(f'График убывания сферичности для {center_freqs[i]} Гц')
    plt.legend()
    plt.show()
