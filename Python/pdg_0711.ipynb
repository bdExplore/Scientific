# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.fft import ifft, fft, fftfreq, fftshift, ifft2, fft2
from scipy.io import wavfile
from scipy.signal import hilbert
from audio_function import *
# Out:
# Данные загружены

# %%
fs, data_micr_calibr =  wavfile.read('/Users/bogda/Desktop/Acoustics/Scientific/Исходные данные/PGD_0711/TASCAM_0098S1.wav')
fs, data_pgd_calibr = wavfile.read('/Users/bogda/Desktop/Acoustics/Scientific/Исходные данные/PGD_0711/TASCAM_0098S2.wav')

fs, data_micr_shum = wavfile.read('/Users/bogda/Desktop/Acoustics/Scientific/Исходные данные/PGD_0711/TASCAM_0099S1.wav')
fs, data_pgd_shum = wavfile.read('/Users/bogda/Desktop/Acoustics/Scientific/Исходные данные/PGD_0711/TASCAM_0099S2.wav')

fs, data_micr_shum_small = wavfile.read('/Users/bogda/Desktop/Acoustics/Scientific/Исходные данные/PGD_0711/TASCAM_0102S1.wav')
fs, data_pgd_shum_small = wavfile.read('/Users/bogda/Desktop/Acoustics/Scientific/Исходные данные/PGD_0711/TASCAM_0102S2.wav')

fs, data_micr_stol = wavfile.read('/Users/bogda/Desktop/Acoustics/Scientific/Исходные данные/PGD_0711/TASCAM_0103S1.wav')
fs, data_pgd_stol = wavfile.read('/Users/bogda/Desktop/Acoustics/Scientific/Исходные данные/PGD_0711/TASCAM_0103S2.wav')

fs, data_micr_porolon = wavfile.read('/Users/bogda/Desktop/Acoustics/Scientific/Исходные данные/PGD_0711/TASCAM_0104S1.wav')
fs, data_pgd_porolon = wavfile.read('/Users/bogda/Desktop/Acoustics/Scientific/Исходные данные/PGD_0711/TASCAM_0104S2.wav')

# %%
# octave_boundaries = np.array([71, 89, 112, 141, 179, 224, 281, 355, 447, 561, 710, 895, 1120, 1410, 1790, 2240, 2810])
# lower_bounds = octave_boundaries[:-1]
# upper_bounds = octave_boundaries[1:]
# center_freqs = np.array([80, 100, 125, 160, 200, 250, 315, 400, 500, 630, 800, 1000, 1250, 1600, 2000, 2500])  # Центральные частоты как середина диапазона
# RMS_microphone_60 = []
# RMS_microphone_120 = []
# RMS_microphone_180 = []
# RMS_microphone_240 = []
# RMS_microphone_315 = []

# %%
octave_boundaries = np.array([71, 89, 112, 141, 179, 224, 281, 355, 447, 561, 710, 895, 1120, 1410, 1790, 2240, 2810, 3550, 4470, 5610, 7100, 8950, 11200])
lower_bounds = octave_boundaries[:-1]
upper_bounds = octave_boundaries[1:]
center_freqs = np.array([80, 100, 125, 160, 200, 250, 315, 400, 500, 630, 800, 1000, 1250, 1600, 2000, 2500, 3150, 4000, 5000, 6300, 8000, 10000])  # Центральные частоты как середина диапазона

# %%
signal = data_micr_shum
t = np.arange(len(signal))/fs
f = fftfreq(len(signal), 1 / fs)
plt.figure(figsize=(16,4))
plt.plot(f, np.abs(fft(signal)), color='blue')
plt.legend()
plt.xlabel("Гц")
plt.ylabel("Амплитуда")
plt.title('Спектр шумового сигнала микрофон 1 эксперимент')
plt.grid(True)

plt.xlim(80, 4000)
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
signal = data_micr_shum_small
t = np.arange(len(signal))/fs
f = fftfreq(len(signal), 1 / fs)
plt.figure(figsize=(16,4))
plt.plot(f, np.abs(fft(signal)), color='blue')
plt.legend()
plt.xlabel("Гц")
plt.ylabel("Амплитуда")
plt.title('Спектр шумового сигнала микрофон 2 эксперимент')
plt.grid(True)

plt.xlim(80, 4000)
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
signal = data_micr_porolon
t = np.arange(len(signal))/fs
f = fftfreq(len(signal), 1 / fs)
plt.figure(figsize=(16,4))
plt.plot(f, np.abs(fft(signal)), color='blue')
plt.legend()
plt.xlabel("Гц")
plt.ylabel("Амплитуда")
plt.title('Спектр шумового сигнала микрофон 4 эксперимент')
plt.grid(True)

plt.xlim(80, 4000)
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
signal = data_micr_stol
t = np.arange(len(signal))/fs
f = fftfreq(len(signal), 1 / fs)
plt.figure(figsize=(16,4))
plt.plot(f, np.abs(fft(signal)), color='blue')
plt.legend()
plt.xlabel("Гц")
plt.ylabel("Амплитуда")
plt.title('Спектр шумового сигнала микрофон 3 эксперимент')
plt.grid(True)

plt.xlim(80, 4000)
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
signal = data_pgd_stol
t = np.arange(len(signal))/fs
f = fftfreq(len(signal), 1 / fs)
plt.figure(figsize=(16,4))
plt.plot(f, np.abs(fft(signal)), color='blue')
plt.legend()
plt.xlabel("Гц")
plt.ylabel("Амплитуда")
plt.title('Спектр шумового сигнала с ПГД на столе')
plt.grid(True)
plt.ylim(0, 3e10)
plt.xlim(80, 4000)
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
signal = data_pgd_shum
t = np.arange(len(signal))/fs
f = fftfreq(len(signal), 1 / fs)
plt.figure(figsize=(16,4))
plt.plot(f, np.abs(fft(signal)), color='blue')
plt.legend()
plt.xlabel("Гц")
plt.ylabel("Амплитуда")
plt.title('Спектр шумового сигнала ПГД большие насадки')
plt.grid(True)
plt.ylim(0, 1e10)
plt.xlim(80, 4000)
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
signal = data_pgd_shum_small
t = np.arange(len(signal))/fs
f = fftfreq(len(signal), 1 / fs)
plt.figure(figsize=(16,4))
plt.plot(f, np.abs(fft(signal)), color='blue')
plt.legend()
plt.xlabel("Гц")
plt.ylabel("Амплитуда")
plt.title('Спектр шумового сигнала ПГД малые насадки')
plt.grid(True)
plt.ylim(0, 1e10)
plt.xlim(80, 4000)
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
t_micr_calibr = np.arange(len(data_micr_calibr))/fs
f_micr_calibr = fftfreq(len(data_micr_calibr), 1 / fs)
plt.figure(figsize=(16,4))
plt.plot(t_micr_calibr, data_micr_calibr, color='blue')
plt.legend()
plt.xlabel("Время (с)")
plt.ylabel("Амплитуда")
plt.ylim(0, 1e8)
plt.grid(True)
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
def spec_avarage (signal, fs, time_interval_sec):
    m = int(len(signal)/fs/time_interval_sec)
    for i in range (0, m):
# Out:
#   Cell In[91], line 4
#
#     ^
# SyntaxError: incomplete input

# %%
# Выделям временной участок, на котором калибровка
t_index = (t_micr_calibr > 10) & (t_micr_calibr < 20)
t_1000Hz = t_micr_calibr[t_index]

data_micr_calibr_94db = data_micr_calibr[t_index]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[54], line 5
#       2 t_index = (t_micr_calibr > 10) & (t_micr_calibr < 20)
#       3 t_1000Hz = t_micr_calibr[t_index]
# ----> 5 data_2209_micr_calibr_1000Hz = data_2209_micr_calibr[t_index]
#
# NameError: name 'data_2209_micr_calibr' is not defined

# %%
amplitudes_microphone = []
for f1, f2 in zip(lower_bounds, upper_bounds):
    data_1_filt = ifft(filt_freq(fft(data_micr_porolon), f1, f2, fs))
    amp = RMS(data_1_filt)
    amplitudes_microphone.append(amp)

amplitudes_microphone = np.array(amplitudes_microphone)

# %%
dB_level_calibr = 20 * np.log10(amplitudes_microphone / 2e-5)
plt.figure(figsize=(16,4))
plt.plot((center_freqs), dB_level_calibr, color='blue')
plt.legend()
plt.xlabel("Частота, Гц")
plt.ylabel("Чувствительность")
plt.grid(True)
plt.xscale('log')
plt.xlim(100, 10001)
plt.ylim(205, 235)
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
import plotly.express as px
import pandas as pd
# Пример твоих массивов X и Y
x_data = center_freqs
y_data = amplitudes_microphone

# Создаем DataFrame
df = pd.DataFrame({
    "Частота, Гц": x_data,
    "Чувствительность, мВ/Па": y_data
})
fig = px.line(
    df,
    x = "Частота, Гц",
    y = "Чувствительность, мВ/Па",
    title = 'Интерактивный Линейный График Чувствительности Микрофона',
    log_x=True,
#    log_x=True
)

# Отображение графика
fig.show()

# %%
data_2209_micr_pa_rms = RMS(data)
dB_level = 20 * np.log10(data_2209_micr_pa_rms / 2e-5)
dB_level
